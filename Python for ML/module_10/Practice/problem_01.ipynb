# %%
import numpy as np
lst = [10,5.4,2,25,17,19,34,20]
arr = np.array(lst)
print(arr)
arr = (arr*1.8) + 32
print(arr)
# Out:
# [10.   5.4  2.  25.  17.  19.  34.  20. ]
# [50.   41.72 35.6  77.   62.6  66.2  93.2  68.  ]
