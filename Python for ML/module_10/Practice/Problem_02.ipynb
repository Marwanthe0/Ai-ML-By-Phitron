# %%
import numpy as np
lst = [5,3,80,43,234,12,54,3,6,24]
arr = np.array(lst)
print(arr)
print(arr.shape)
print(arr.size)
print(arr.dtype)
arr2 = arr/60
print(arr2)
# Out:
# [  5   3  80  43 234  12  54   3   6  24]
# (10,)
# 10
# int64
# [0.08333333 0.05       1.33333333 0.71666667 3.9        0.2
#  0.9        0.05       0.1        0.4       ]
