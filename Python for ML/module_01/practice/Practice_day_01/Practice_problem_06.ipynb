# %%
try:
    with open("story.txt","r") as f:
        lns = f.readlines()
except Exception as e:
    print(e)
else:
    print("There are",len(lns),"lines in thes file")
finally:
    print("Done")
# Out:
# There are 9 lines in thes file
# Done
