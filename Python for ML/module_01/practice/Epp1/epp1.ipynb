# %%
with open("emails.txt","r") as f:
    content = f.readlines()
    # content = list(map(lambda x:x.strip(),content))
    content = [x.casefold() for x in content]
    content = list(set(content))
    content = sorted(content)
    content = "".join(content)
    print(content)
with open("unique_emails.txt","w") as f2:
    f2.write(content)
# Out:
# abcd@gmail.com
# ahmed@gmail.com
# fdlasjfdanfd@gmail.com
# marwnthe0@gmail.com
# nothaofahdsf@gmail.comsdlfjasfja44@gmail.com
