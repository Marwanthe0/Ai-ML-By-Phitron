# %% [markdown]
# Problem_01

# %%
#importing libraries and Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
student = pd.read_csv("student_IQdata.csv")
student.head(5)
# Out:
#    Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0       13.5         2.0            17.7        72
# 1        8.0        18.0             5.0        75
# 2        6.4         7.2            22.7        78
# 3        6.9         8.7             6.6       110
# 4       10.5         8.6             5.8       104

# %%
#Problem_01
sns.scatterplot(data = student,x = "Study_Hour",y = "IQ_Score",size = "Shoe_Size")
# Out:
# <Axes: xlabel='Study_Hour', ylabel='IQ_Score'>

# %% [markdown]
# Problem_02

# %%
sns.scatterplot(data=student, x="Shoe_Size", y="Study_Hour")
# Out:
# <Axes: xlabel='Shoe_Size', ylabel='Study_Hour'>

# %%
fig = px.histogram(student,x = "Shoe_Size",nbins = 8)
fig.show()
